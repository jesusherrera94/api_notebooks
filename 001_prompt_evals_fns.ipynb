# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        # "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.166666666666666

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\n\ndef extract_s3_bucket(s3_uri):\n    match = re.match(r's3://([a-zA-Z0-9\\-\\.]+)(?:/|$)', s3_uri)\n    if match:\n        return match.group(1)\n    return None\n",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from a full S3 URI (e.g., s3://my-bucket/path/to/file.txt) and extract just the bucket name",
#       "format": "regex"
#     },
#     "score": 8.0,
#     "reasoning": "The solution works for standard s3:// URIs but has notable limitations. The regex pattern is overly permissive (allows uppercase) and doesn't fully comply with AWS S3 bucket naming constraints. While it handles the basic happy path, it lacks robustness for edge cases and input validation. For production use, AWS SDK functions like parsing with boto3 or stricter validation would be preferable."
#   },
#   {
#     "output": "\n{\n  \"FunctionName\": \"my-lambda-function\",\n  \"Runtime\": \"python3.11\",\n  \"Timeout\": 30,\n  \"MemorySize\": 256,\n  \"Role\": \"arn:aws:iam::123456789012:role/lambda-role\",\n  \"Handler\": \"index.handler\",\n  \"Code\": {\n    \"ZipFile\": \"\"\n  }\n}\n",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function that specifies the function name, runtime (Python 3.11), timeout (30 seconds), and memory size (256 MB)",
#       "format": "json"
#     },
#     "score": 8.5,
#     "reasoning": "The solution successfully addresses all core requirements with technically correct AWS Lambda configuration syntax. However, it exceeds the scope by adding unrequested fields and includes a non-functional Code section. While these additions demonstrate AWS best practices (Role and Handler are required for actual Lambda deployment), they contradict the task's minimal specification request. The solution would benefit from either strict adherence to requirements or clear documentation of additions."
#   },
#   {
#     "output": "\nimport re\n\ndef format_cloudwatch_log_group(log_group_name: str) -> str:\n    \"\"\"\n    Formats an AWS CloudWatch log group name to standard format /aws/lambda/function-name.\n    Handles any leading or trailing slashes.\n    \"\"\"\n    # Remove leading and trailing slashes\n    cleaned = log_group_name.strip('/')\n    \n    # Ensure the format starts with /aws/lambda/\n    if not cleaned.startswith('aws/lambda/'):\n        # If it's just a function name, prepend the standard prefix\n        cleaned = f'aws/lambda/{cleaned}'\n    \n    # Return with leading slash\n    return f'/{cleaned}'\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS CloudWatch log group name and returns it in the standard format /aws/lambda/function-name, handling any leading or trailing slashes",
#       "format": "python"
#     },
#     "score": 8.0,
#     "reasoning": "The solution addresses the core requirement of normalizing CloudWatch log group names with leading/trailing slash handling. However, it makes overly broad assumptions about input format without validation. The unused regex import indicates potential incomplete implementation. The function would benefit from input validation to handle edge cases like empty strings, None values, or log group names that don't follow AWS naming conventions. Additionally, the logic for detecting whether to prepend 'aws/lambda/' is too simplistic and could produce incorrect results for valid log group names that don't follow the standard Lambda naming pattern."
#   }
# ]
