# %%
# install dependencies
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in /opt/anaconda3/lib/python3.13/site-packages (1.7.0)
# Requirement already satisfied: python-dotenv in /opt/anaconda3/lib/python3.13/site-packages (1.1.0)
# Requirement already satisfied: anyio<5,>=4.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from anthropic) (4.10.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /opt/anaconda3/lib/python3.13/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx2<3,>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from anthropic) (2.13.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from anthropic) (0.17.0)
# Requirement already satisfied: pydantic<3,>=1.10.0 in /opt/anaconda3/lib/python3.13/site-packages (from anthropic) (2.12.4)
# Requirement already satisfied: sniffio<2,>=1 in /opt/anaconda3/lib/python3.13/site-packages (from anthropic) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /opt/anaconda3/lib/python3.13/site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.13/site-packages (from anyio<5,>=4.1.0->anthropic) (3.20)
# Requirement already satisfied: httpcore2==2.13.0 in /opt/anaconda3/lib/python3.13/site-packages (from httpx2<3,>=2.0.0->anthropic) (2.13.0)
# Requirement already satisfied: truststore>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from httpx2<3,>=2.0.0->anthropic) (0.10.1)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from httpcore2==2.13.0->httpx2<3,>=2.0.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.10.0->anthropic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.10.0->anthropic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.10.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load env variable
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5-20251001"

# %%
def add_user_message(messages, text):
    user_message = { "role": "user", "content": text}
    messages.append(user_message)
def add_assistant_message(messages, text):
    assistant_message = { "role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
    model = model,
    max_tokens = 1000,
    messages = messages
    )
    return message.content[0].text

# Make a request

# %%
# make a starting list of messages
messages = []
# Add in the initial user question of "define quantum computing in one sentence"
add_user_message(messages, "define quantum computing in one sentence")
messages
# Pass the lits of messages into 'chat' to get an answer
answer = chat(messages)
# Take the answer and add it as an assistant message into our list
add_assistant_message(messages, answer)
# add in the user's following-up question
add_user_message(messages, "write another sentence")
# call chat again with the list of messages to get a final answer
answer = chat(messages)
add_assistant_message(messages, answer)
messages
# Out:
# [{'role': 'user', 'content': 'define quantum computing in one sentence'},
#  {'role': 'assistant',
#   'content': '# Quantum Computing\n\nQuantum computing uses quantum bits (qubits) that exploit superposition and entanglement to process multiple possible solutions simultaneously, enabling exponentially faster computation for certain types of problems compared to classical computers.'},
#  {'role': 'user', 'content': 'write another sentence'},
#  {'role': 'assistant',
#   'content': '# Quantum Computing\n\nQuantum computing uses quantum bits (qubits) that exploit superposition and entanglement to process multiple possible solutions simultaneously, enabling exponentially faster computation for certain types of problems compared to classical computers. Unlike classical bits that exist as either 0 or 1, qubits can exist in both states at once until measured, allowing quantum computers to explore vast solution spaces in parallel.'}]
